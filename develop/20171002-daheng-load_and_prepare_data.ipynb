# %% [markdown]
# # Load and prepare data
# **Objective**: Load news and tweets data from raw file into sqlite3 db.

# %% [markdown]
# # Roadmap
# 1. Copy raw data file to DATA_DIR, unzip and check format.
# 2. Create db. Build tables for news and tweets.
# 3. Bulk load news and tweets data into db.
# 4. Check basic statistics.
# 4. Build df pickles for news and tweets over selected period

# %% [markdown]
# # Steps

# %%
"""
Initialization
"""

'''
Standard modules
'''
import os
import sqlite3
import csv
from pprint import pprint

'''
Analysis modules
'''
import pandas as pd

'''
Custom modules
'''
import config
import utilities

'''
Misc
'''
nb_name = '20171002-daheng-load_and_prepare_data'

# %% [markdown]
# ## Copy raw data file to DATA_DIR, unzip and check format

# %% [markdown]
# Raw data are located inside raw-news_tweets-meng/ folder in DATA_DIR.

# %%
! ls -1 ./data/raw-news_tweets-meng/
# Out:
# dataset1
# dataset2
# readme.txt
# volume.txt

# %%
! ls -1 ./data/raw-news_tweets-meng/dataset1
# Out:
# news.txt
# tweets.txt

# %% [markdown]
# ### Check format of news data:

# %%
! head -2 ./data/raw-news_tweets-meng/dataset1/news.txt
# Out:
# POST_TIME	NEWS_SOURCE	NEWS_TITLE	NEWS_DOC
# 2014-11-18 00:03:28	Times of India	India sixth worst affected country by terrorism in 2013: Report	LONDON: India was the sixth worst affected country by terrorism in 2013 — the other five being war zones at present. :::::::::::::::: As many as 43 different terrorist groups categorized into three groups: Islamists, separatists and communists have been found to have planned and carried out attacks in India. :::::::::::::::: The world witnessed 10,000 terrorist attacks in 2013, a 44% increase from the previous year. India, however, witnessed a much higher increase of terrorist attacks during the same period — while terrorism increased by 70% in India from 2012 to 2013, the number of deaths increased from 238 to 404. :::::::::::::::: Globally, the number of deaths from terrorism increased by 61%, according to the Global Terrorism Index 2014. :::::::::::::::: The report says that in India, there remains significant terrorist activity, including on the border between India and Pakistan. :::::::::::::::: Over 80% of the deaths from terrorist incidents in 2013 were recorded in just five countries: Iraq, Afghanistan, Pakistan, Nigeria and Syria. :::::::::::::::: On a scale of 1 (lowest impact of terrorism) to 10 (highest risk of terrorism) — Iraq which has emerged as the world's worst affected country with terrorism is the only entry with a score of 10. :::::::::::::::: India which is ranked sixth has a score of 7.86. :::::::::::::::: The largest year-on-year increase in deaths from terrorism was recorded between 2012 and 2013 increasing from 11,133 to 17,958. :::::::::::::::: As many as 87 countries experienced a terrorist incident in 2013, slightly up from 81 in 2012. :::::::::::::::: The number of countries experiencing over 50 deaths in one year hit an all-time high in 2013 at 24, five greater than the previous high of 19 countries in 2008. :::::::::::::::: The Global Index said about India — "The number of attacks also increased, with 55 more attacks in 2013 than 2012. However, the majority of terrorist attacks in India have low casualties. In 2013 around 70% of attacks were non-lethal. Communist terrorist groups are by far the most frequent perpetrators and the main cause of deaths in India. Three Maoist communist groups claimed responsibility for 192 deaths in 2013, which was nearly half of all deaths from terrorism in India. Police are overwhelmingly the biggest targets of Maoists, accounting for half of all deaths and injuries. This is mainly through armed assaults, which killed 85, and bombings and explosions, which killed 43". :::::::::::::::: The dispute with Pakistan over Jammu & Kashmir is the source of Islamic terrorism in India, according to the report. In 2013, three Islamist groups were responsible for around 15% of deaths in India. This includes Hizbul Mujahideen which was the only group in India to use suicide tactics in 2013. :::::::::::::::: "Islamist groups in India commonly use armed assaults targeting the police or bombings targeting private citizens. The majority of attacks occur in Hyderabad and Jammu & Kashmir. In September 2014, al-Qaida announced its presence in India, hoping to unite other Islamist groups," the report says. :::::::::::::::: Globally, four terrorist groups — al-Qaida, Boko Haram, IS and the Taliban were responsible for 66% of all deaths from terrorist attacks in 2013 in which the perpetrator is known. :::::::::::::::: Deaths from other groups operating in Pakistan, Syria, Somalia, India and Kenya, account for a further 21% of deaths in the same year. Prominent groups operating in these countries include the Al-Nusrah Front in Syria, Al-Shabaab in Somalia and Kenya, Lashkar-e-Jhangvi in Pakistan and Maoists in India. :::::::::::::::: In total there have been over 48,000 terrorist incidents over the last 14 years claiming over 1,07,000 lives. Terrorism has increased dramatically with even conservative estimates suggesting a fivefold surge since the year 2000. :::::::::::::::: In 2013 alone,  ...

# %% [markdown]
# ### Check format of tweets data:

# %%
! head -5 ./data/raw-news_tweets-meng/dataset1/tweets.txt
# Out:
# POST_TIME	TWEET_TEXT
# 2014-11-10 08:47:19	x + 'Suicide car bomber kills three foreign troops in Afghan capital ...
# 2014-11-10 14:47:37	x + 'Suicide car bomber kills 3 foreign troops in Afghan capital ...
# 2014-11-10 15:48:21	Suicide Attack At Cafe In Iraqi Capital Kills 12
# 2014-11-11 04:44:54	@AlphaTwat yes! 52 at 630am and by 730 it was 18 with blowing snowstorms! This part of the world is crazy.

# %% [markdown]
# ## Create db. Build tables for news and tweets.

# %% [markdown]
# ### Define DDL scripts to create db, table schema for news, and table schema for tweets

# %%
"""
Register
    NEWS_TWEETS_DDL_FILE = os.path.join(DATA_DIR, 'news_tweets-meng.schema.sql')
in config.
"""

# %%
! cat ./data/news_tweets-meng.schema.sql
# Out:
# -- news_tweets-meng.schema.sql
#
# -- Schema for news and tweets data
#
# -- News table
# create table news (
#     news_id integer primary key autoincrement not null,
#     post_time datetime,
#     news_source text,
#     news_title text,
#     news_doc text
# );
#
# -- Tweets table
# create table tweets (
#     tweet_id integer primary key autoincrement not null,
#     post_time datetime,
#     tweet_text text
# );

# %% [markdown]
# ### Build db and talbes

# %%
"""
Register 
    NEWS_TWEETS_DB = os.path.join(DATA_DIR, 'news_tweets-meng.db')
in config.
"""
def check_db():
    db_exists = os.path.exists(config.NEWS_TWEETS_DB_FILE)
    
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        if not db_exists:
            print('No db exists. Creating new db and tables...')
            with open(config.NEWS_TWEETS_DDL_FILE, 'r') as f:
                schema = f.read()
                conn.executescript(schema)
        else:
            print('db already exists!')

# %%
if 1 == 1:
    check_db()
# Out:
# db already exists!

# %% [markdown]
# ### Bulk load news and tweets into db

# %%
# %%time
"""
News data

Note: should be executed two times
 - data/raw-news_tweets-meng/dataset1/news.txt
 - data/raw-news_tweets-meng/dataset2/news.txt
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        with open(os.path.join(config.DATA_DIR, 'raw-news_tweets-meng/dataset2/news.txt'), 'r') as f:
            news_df_chunksize = 10000
            for df_chunk in pd.read_csv(f, sep='\t', chunksize=news_df_chunksize, iterator=True):
                column_names = {
                    'POST_TIME': 'post_time',
                    'NEWS_SOURCE': 'news_source',
                    'NEWS_TITLE': 'news_title',
                    'NEWS_DOC': 'news_doc'
                }
                df_chunk = df_chunk.rename(columns=column_names)
                df_chunk.to_sql(name='news', con=conn, if_exists='append', index=False)
# Out:
# CPU times: user 1.38 s, sys: 368 ms, total: 1.75 s
# Wall time: 3.32 s

# %%
# %%time
"""
Tweets data

Note: should be executed two times
 - data/raw-news_tweets-meng/dataset1/tweets.txt
 - data/raw-news_tweets-meng/dataset2/tweets.txt
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        with open(os.path.join(config.DATA_DIR, 'raw-news_tweets-meng/dataset2/tweets.txt'), 'r') as f:
            tweets_df_chunksize = 100000
            for df_chunk in pd.read_csv(f, sep='\t', chunksize=tweets_df_chunksize, iterator=True):
                column_names = {
                    'POST_TIME': 'post_time',
                    'TWEET_TEXT': 'tweet_text'
                }
                df_chunk = df_chunk.rename(columns=column_names)
                df_chunk.to_sql(name='tweets', con=conn, if_exists='append', index=False)
# Out:
# CPU times: user 22.2 s, sys: 1.9 s, total: 24.1 s
# Wall time: 29.6 s

# %%
# %%time
"""
Tweets table is too large. Build index on post_time field.
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        cursor = conn.cursor()
        query = '''
        create index tweets_post_time on tweets(post_time);
        '''
        cursor.execute(query)
# Out:
# CPU times: user 1min 3s, sys: 9.23 s, total: 1min 12s
# Wall time: 1min 23s

# %%
"""
List out tables and indices
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        cursor = conn.cursor()
        query = """
        select name from sqlite_master
        where type = 'table';
        """
        cursor.execute(query)
        print('TABLES:')
        print(cursor.fetchall())
        
        query = """
        select name from sqlite_master
        where type = 'index'
        """
        cursor.execute(query)
        print('INDICES:')
        print(cursor.fetchall())
# Out:
# TABLES:
# [('news',), ('sqlite_sequence',), ('tweets',)]
# INDICES:
# [('tweets_post_time',)]

# %% [markdown]
# ### Check basic statistics

# %%
"""
Check number of news per day
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        conn.row_factory = sqlite3.Row
        cursor = conn.cursor()
        
        query = '''
        select date(post_time) as news_date, count(news_id) as news_num
        from news
        group by date(post_time);
        '''
        
        cursor.execute(query)
        for row in cursor.fetchall():
            print('{}: {}'.format(row['news_date'], row['news_num']))
# Out:
# 2014-11-18: 290
# 2014-11-19: 267
# 2014-11-20: 320
# 2014-11-21: 293
# 2014-11-22: 260
# 2014-11-23: 275
# 2014-11-24: 274
# 2014-11-25: 323
# 2014-11-26: 307
# 2014-11-27: 287
# 2014-11-28: 291
# 2014-11-29: 250
# 2014-11-30: 263
# 2014-12-01: 323
# 2014-12-02: 291
# 2014-12-03: 293
# 2014-12-04: 283
# 2014-12-05: 288
# 2014-12-06: 233
# 2014-12-07: 262
# 2014-12-08: 292
# 2014-12-09: 272
# 2014-12-10: 284
# 2014-12-11: 284
# 2014-12-12: 254
# 2014-12-13: 231
# 2014-12-14: 149
# 2014-12-16: 47
# 2014-12-17: 313
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        conn.row_factory = sqlite3.Row
        cursor = conn.cursor()
        
        query = """
        select date(post_time) as tweet_date, count(tweet_id) as tweets_num
        from tweets
        where post_time between '2014-11-10' and '2014-11-22'
        group by date(post_time);
        """
        
        cursor.execute(query)
        for row in cursor.fetchall():
            print('{}: {}'.format(row['tweet_date'], row['tweets_num']))
# Out:
# 2014-11-10: 3
# 2014-11-11: 8
# 2014-11-12: 7
# 2014-11-13: 12
# 2014-11-14: 10
# 2014-11-15: 12
# 2014-11-16: 24
# 2014-11-17: 77
# 2014-11-18: 142824
# 2014-11-19: 287755
# 2014-11-20: 324073
# 2014-11-21: 275824
# CPU times: user 1.52 s, sys: 80 ms, total: 1.6 s
# Wall time: 1.59 s

# %% [markdown]
# ### Build df pickles for news and tweets over selected period
# Select out news and tweets data from (3) dataset1: 2015-01-01 to 2015-03-21 according to readme.txt file of raw dataset

# %%
# %%time
"""
Build pickle for news data over selected period.

Register
    NEWS_PERIOD_DF_PKL = os.path.join(DATA_DIR, 'news-period.df.pkl')
in config.
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        query = """
        select news_id, post_time, news_source, news_title, news_doc from news
        where post_time between '2015-01-01' and '2015-03-22';
        """
        
        news_period_df = pd.read_sql_query(sql=query,con=conn,parse_dates=['post_time'])
        
        news_period_df.to_pickle(config.NEWS_PERIOD_DF_PKL)
# Out:
# CPU times: user 568 ms, sys: 560 ms, total: 1.13 s
# Wall time: 4.22 s

# %%
# %%time
"""
Build pickle for tweets data over selected period.

Register
    TWEETS_PERIOD_DF_PKL = os.path.join(DATA_DIR, 'tweets-period.df.pkl')
in config.
"""
if 0 == 1:
    with sqlite3.connect(config.NEWS_TWEETS_DB_FILE) as conn:
        query = """
        select tweet_id, post_time, tweet_text from tweets
        where post_time between '2015-01-01' and '2015-03-22';
        """
        
        tweets_period_df = pd.read_sql_query(sql=query,con=conn,parse_dates=['post_time'])
        
        tweets_period_df.to_pickle(config.TWEETS_PERIOD_DF_PKL)
# Out:
# CPU times: user 2min 29s, sys: 26.4 s, total: 2min 56s
# Wall time: 3min 29s

# %%
# %%time
"""
Test recover df pickle
"""
if 1 == 1:
    news_period_df = pd.read_pickle(config.NEWS_PERIOD_DF_PKL)
    tweets_period_df = pd.read_pickle(config.TWEETS_PERIOD_DF_PKL)
# Out:
# CPU times: user 12.4 s, sys: 6.07 s, total: 18.5 s
# Wall time: 31.7 s

# %%
news_period_df
# Out:
#        news_id           post_time                   news_source  \
# 0        10965 2015-01-01 00:03:09                      CBS News
# 1        10966 2015-01-01 00:03:26                        CBC.ca
# 2        10967 2015-01-01 00:04:41                      ABC News
# 3        10968 2015-01-01 00:04:41                  The Guardian
# 4        10969 2015-01-01 00:06:16                      NOLA.com
# 5        10970 2015-01-01 00:08:39                    Philly.com
# 6        10971 2015-01-01 00:09:14                      Ynetnews
# 7        10972 2015-01-01 00:12:44               Washington Post
# 8        10973 2015-01-01 00:16:27                      ABC News
# 3      Potential Republican presidential candidate Je...
# 4      PYONGYANG, North Korea -- North Korean leader ...
# 5      Ryan Winn bundles up son Ian as they wait for ...
# 6      Following the Palestinian defeat at the UN Sec...
# 7      CAIRO — Here is a look at the major events in ...
# 8      Bundled-up revelers planning to usher in 2015 ...
# 9      Bundled-up revelers planning to usher in 2015 ...
# 10     Here is a look at the major events in the arre...
# 11     Bundled-up revelers planning to usher in 2015 ...
# 12     Bundled-up revelers planning to usher in 2015 ...
# 13     An appeals court in Egypt has ordered a retria...
# 14     PYONGYANG, North Korea North Korean leader Kim...
# 15     BENSON, Ariz. Two people were killed in a heli...
# 16     CAIRO (AP) — An Egyptian appeals court ordered...
# 17     PYONGYANG, North Korea (AP) — North Korean lea...
# 18     SHANGHAI — People unable to contact friends an...
# 19     The page you've requested either does not exis...
# 20     A rocket fired amid fighting between Taliban i...
# 21     North Korean leader Kim Jong Un guides the mul...
# 22     Hong Kong (CNN) -- Zuo Zhijian says the heavy ...
# 23     The move, taken a day after the failure of a P...
# 24     Jeb Bush is clearing a path for a 2016 preside...
# 25     North Korean leader Kim Jong-un has said he is...
# 26     A million people crammed into New York's Times...
# 27     New Delhi:Terming the ceasefire violations by ...
# 28     LOS ANGELES: A second suspect has been arreste...
# 29     Can you live in Idaho and not love potatoes? I...
# ...                                                  ...
# 22028  Bobbi Kristina Brown, the daughter of late pop...
# 22029  The U.S. has removed all remaining personnel f...
# 22030  WASHINGTON — The Justice Division is investiga...
# 22031  Authorities are building a criminal case again...
# 22032  Predators 3, Sabres 0: Pekka Rinne posted his ...
# 22033  After trailing at halftime with President Obam...
# 22034  The Obama administration issued the first fede...
# 22035  Footage released by the Tunisian interior mini...
# 22036  The rims seemed tight. So did Villanova.::::::...
# 22037  Senator will be first declared GOP candidate::...
# 22038                                               None
# 22039  Even though new standards regulating hydraulic...
# 22040  The machete-wielding man who attacked two Tran...
# 22041  SEATTLE — Gonzaga began the game pressing Nort...
# 22042  Millionaire Robert Durst was illegally arreste...
# 22043  LINDEN, N.J. (AP) — Police are investigating w...
# 22044  Thousands of people on Friday flocked to get a...
# 22045  COLUMBUS, Ohio — To earn a spot in the main po...
# 22046  Seattle, WA (SportsNetwork.com) - Kyle Wiltjer...
# 22047  The Colorado woman accused of cutting open a s...
# 22048  Thank you for reading 10 free articles on our ...
# 22049  KGW-TV reports that one of those error message...
# 22050  Cape Town - Thousands of people on Friday floc...
# 22051  Dayton never gets tired — of winning.::::::::D...
# 22052  NEW YORK (AP) — The U.S. must release photogra...
# 22053  Dayton’s Scoochie Smith (11) celebrates late i...
# 22054  The site is currently under maintenance, we wi...
# 22055  Multiple suicide bombings, claimed by the Isla...
# 22056  Dozens of aging U.S. veterans gathered on the ...
# 22057  SALEM, Ore. (AP) — A "main technical glitch" i...
#
# [22058 rows x 5 columns]

# %%
news_period_df.dtypes
# Out:
# news_id                 int64
# post_time      datetime64[ns]
# news_source            object
# news_title             object
# news_doc               object
# dtype: object

# %%
tweets_period_df
# Out:
# 6         Fuck Doug Marrone. I hope he takes Hackett wit...
# 7         You get rid of Rex Ryan for Doug Marrone?!? Lm...
# 8         Bills: Owner Terry Pegula says he's "disappoin...
# 9         Jets: Team will have strong interest in ex-Bil...
# 10              “@allyssa520: Doug Marrone ain't shit 😡👊✌️”
# 11        Oh god, i hope not. RT "@JoeandEvan: Doug Marr...
# 12        Well Doug Marrone comes full circle as a compl...
# 13        @BuckyBrooks @richeisen So Doug Marrone's agen...
# 14        “@KiwiMutt: And now announcing your new Jets c...
# 15        Doug Marrone must be targeting that University...
# 16        Few people are "winning off the field" more th...
# 17               @airjan23 you can have Doug Marrone!!! LOL
# 18        How could Doug Marrone opt out of a 9-7 team a...
# 19        😂 RT “@MMehtaNYDN: Jets source on possibility ...
# 20        Doug Marrone pulled a G-Move on the Bills play...
# 21        @woodyjohnson4 Woody, we don't need Doug Marro...
# 22        Marrone was my least favorite #Bills coach eve...
# 23        It wouldn't make sense to me to bring in a coa...
# 24        Never shoulda let Doug Marrone watch The Secre...
# 25        Really? Pretty underwhelming. RT @AdamSchefter...
# 26        @Atlanta_Falcons - hire Doug Marrone and sign ...
# 27        Could Doug Marrone be the next NY Jets head co...
# 28        To opt out of his contract after going 9-7, yo...
# 29        “@BartHubbuch: Why would Doug Marrone be an up...
# ...                                                     ...
# 26208735  Over/Under how many "former Dallas Star, Brad ...
# 26208736  Actually shaking with anger, just wait until I...
# 26208737  i really miss dean brown doing the play by pla...
# 26208738  In many cases, the addition of children brings...
# 26208739  DAMN, so unfortunate, games getting closer and...
# 26208740  @Lillyroma1 I'm sure there are many who would ...
# 26208741  I just saw my first flying insect of the year ...
# 26208742  #RenewEyeCandy because so many boring and poin...
# 26208743  @Perednia She didn't know how many were on dri...
# 26208744  Hey kool aid and frozen pizza, It's a work of ...
# 26208745          So many people annoy the fuck out of me😂😂
# 26208746  @George_Fordy  Well done today. Great game and...
# 26208747  said many times before the turn of the year th...
# 26208748  @netanyahu congratulations. I wish we had a le...
# 26208749  @duchovlet @HannahSky @DAVID_LYNCH @Festival_C...
# 26208750  There are entirely too many white people in Sa...
# 26208751  “@MellowMeag: “@ImTrouble_Bye: I have to party...
# 26208752  One Step Closer by Linkin Park is basically th...
# 26208753  @shaek066 @AmareshMisraFC @riwired not as many...
# 26208754  @RadMama88 If you're talking about the skinny ...
# 26208755  But I'm holding you closer than most,  'Cause ...
# 26208756  Obama says compensation for college athletes w...
# 26208757  @Lord_Chancellor it's almost finished, I think...
# 26208758  I just wanna see how many of wore the same exa...
# 26208759  nobel ceremony on NRK.no: obama gaunt, aged 20...
# 26208760  So many industry whores in the rap game and in...
# 26208761  @Fffeisty @gosensgo101 How many fly by's have ...
# 26208762  Is there a set number how many is allowed to d...
# 26208763  I'm not sure if I own enough long-sleeve butto...
# 26208764  'They hate us for our freedom' or 'They hate t...
#
# [26208765 rows x 3 columns]

# %%
tweets_period_df.dtypes
# Out:
# tweet_id               int64
# post_time     datetime64[ns]
# tweet_text            object
# dtype: object
